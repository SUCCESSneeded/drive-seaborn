# %% [markdown]
# <a href="https://colab.research.google.com/github/tanujakarkhile11/drive-seaborn/blob/main/sea1subplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **scatter plot**

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

tips = {
    "total_bill": [16.99, 10.34, 21.01, 23.68, 24.59, 25.29, 8.77, 26.88, 15.04, 14.78, 10.27, 35.26, 15.42, 18.43, 14.83, 21.58, 10.33, 16.29, 16.97, 20.65],
    "smoker": ["No", "No", "No", "Yes", "No", "No", "No", "No", "Yes", "No", "No", "No", "No", "No", "Yes", "No", "No", "No", "No", "No"],
    "sex": ["Female", "Male", "Male", "Male", "Female", "Male", "Male", "Male", "Male", "Male", "Male", "Female", "Male", "Male", "Female", "Male", "Female", "Male", "Female", "Male"],
    "day": ["Sun", "Sun", "Sun", "Sun", "Sun", "Sun", "Sun", "Sun", "Sun", "Sun", "Sun", "Sun", "Sun", "Sun", "Sun", "Sun", "Sun", "Sun", "Sun", "Sun"],
    "time": ["Dinner", "Dinner", "lunch", "Dinner", "Dinner", "lunch", "Dinner", "lunch", "Dinner", "lunch", "Dinner", "Dinner", "Dinner", "Dinner", "Dinner", "Dinner", "Dinner", "Dinner", "Dinner", "Dinner"],
    "size": [2, 3, 3, 2, 4, 4, 2, 4, 2, 2, 2, 4, 2, 4, 2, 2, 5, 3, 3, 3],
    "tip": [1.01, 1.66, 3.50, 3.31, 3.61, 4.71, 2.00, 3.12, 1.96, 3.23, 1.71, 5.00, 1.57, 3.00, 3.02, 3.92, 1.67, 3.51, 3.50, 3.35]
}

# Create the DataFrame
df = pd.DataFrame(tips)

# Display the first few rows
print(df.head())
# Out:
#    total_bill smoker     sex  day    time  size   tip
# 0       16.99     No  Female  Sun  Dinner     2  1.01
# 1       10.34     No    Male  Sun  Dinner     3  1.66
# 2       21.01     No    Male  Sun   lunch     3  3.50
# 3       23.68    Yes    Male  Sun  Dinner     2  3.31
# 4       24.59     No  Female  Sun  Dinner     4  3.61

# %%
#axes level function
sns.scatterplot(data=tips,x='total_bill',y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
#relplot -> gives same graph as scatter plot
#figure level

sns.relplot(data=tips,x='total_bill',y='tip',kind='scatter')

# %%
sns.scatterplot(data=tips,x='total_bill',y='tip',hue='sex',style='time',size='size')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
#seaborn.scatterplot(data=None, *, x=None, y=None, hue=None, size=None, style=None,
#palette=None, hue_order=None, hue_norm=None, sizes=None, size_order=None, size_norm=None, markers=True, style_order=None, legend='auto', ax=None, **kwargs)
sns.scatterplot(data=tips, x="total_bill", y="tip", hue="size",style='size')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip", hue="size", palette='colorblind')
#palette-> deep,dark,"muted", "bright", "pastel",colorblind
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
#dataframe.eval()-> MODIFY THE COLUMN OF DATAFRAME

tips1=pd.DataFrame(tips)
tip = tips1.eval("tip / total_bill").rename("tip_rate")
sns.scatterplot(data=tips, x="total_bill", y="tip", hue=tip)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
#Control the range of marker areas with sizes, and set legend="full" to force every unique value to appear in the legend:

sns.scatterplot(
    data=tips, x="total_bill", y="tip", hue="size", size="size",
    sizes=(20, 200), legend="full"
)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
#hue_norm to control the quantitative hue mapping:

sns.scatterplot(
    data=tips, x="total_bill", y="tip", hue="size", size="size",
    sizes=(20, 200), hue_norm=(0, 6), legend="full"
)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
markers = {"lunch": "s", "Dinner": "X"}
sns.scatterplot(data=tips, x="total_bill", y="tip", style="time",hue='size',hue_norm=(0,7),size='size',legend='auto',sizes=(0,200), markers=markers)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# # Additional keyword arguments

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip", s=100, color="red", marker="+")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
index = pd.date_range("1 1 2000", periods=100, freq="m", name="date")  #daterange->parameters ->(start,end,freq),(start,periods='',freq)
data = np.random.randn(100, 4).cumsum(axis=0)  #cumsum keeps on adding previous values to the current value
wide_df = pd.DataFrame(data, index, ["a", "b", "c", "d"])
sns.scatterplot(data=wide_df)
# Out:
# /tmp/ipykernel_4331/2375788259.py:1: FutureWarning: 'm' is deprecated and will be removed in a future version, please use 'ME' instead.
#   index = pd.date_range("1 1 2000", periods=100, freq="m", name="date")  #daterange->parameters ->(start,end,freq),(start,periods='',freq)
# <Axes: xlabel='date'>

# %% [markdown]
# # RELPLOT

# %%
#REPLOT IS FIGURE LEVEL FUNCTION
#replot is better than to use facetgrid directly. It is use to combine facetgrid and scatterplot
""" relplot(data=None, *, x=None, y=None, hue=None, size=None, style=None, units=None, weights=None, row=None, col=None, col_wrap=None,
row_order=None, col_order=None, palette=None, hue_order=None, hue_norm=None, sizes=None, size_order=None, size_norm=None, markers=None,
dashes=None, style_order=None, legend='auto', kind='scatter', height=5, aspect=1, facet_kws=None, **kwargs)
Figure-level interface for drawing relational plots onto a FacetGrid. """
# Out:
# " relplot(data=None, *, x=None, y=None, hue=None, size=None, style=None, units=None, weights=None, row=None, col=None, col_wrap=None,\nrow_order=None, col_order=None, palette=None, hue_order=None, hue_norm=None, sizes=None, size_order=None, size_norm=None, markers=None,\ndashes=None, style_order=None, legend='auto', kind='scatter', height=5, aspect=1, facet_kws=None, **kwargs)\nFigure-level interface for drawing relational plots onto a FacetGrid. "

# %%
sns.relplot(data=tips,x='size',y='total_bill',hue='sex')

# %%
sns.relplot(data=tips,x='size',y='total_bill',hue='sex',col='time',row='sex')

# %%
sns.relplot(data=tips, x="total_bill", y="tip", hue="time", col="time", col_wrap=2)

# %%
frmi = pd.DataFrame({
    "subject": [
        "s13", "s5", "s12", "s11", "s10",
        "s1", "s2", "s3", "s4", "s6",
        "s7", "s8", "s9", "s14", "s15"
    ],

    "timepoint": [
        18, 14, 18, 18, 18,
        12, 14, 16, 18, 20,
        12, 14, 16, 18, 20
    ],

    "event": [
        "stim", "stim", "stim", "stim", "stim",
        "rest", "stim", "rest", "stim", "rest",
        "stim", "rest", "stim", "rest", "stim"
    ],

    "region": [
        "parietal", "parietal", "parietal", "parietal", "parietal",
        "frontal", "frontal", "frontal", "frontal", "frontal",
        "temporal", "temporal", "temporal", "temporal", "temporal"
    ],

    "signal": [
        -0.017552, -0.080883, -0.081033, -0.046134, -0.037970,
         0.025421, -0.063215,  0.014532, -0.052341,  0.031245,
        -0.024531,  0.018642, -0.071235,  0.042156, -0.035821
    ]
})

print(frmi)
# Out:
#    subject  timepoint event    region    signal
# 0      s13         18  stim  parietal -0.017552
# 1       s5         14  stim  parietal -0.080883
# 2      s12         18  stim  parietal -0.081033
# 3      s11         18  stim  parietal -0.046134
# 4      s10         18  stim  parietal -0.037970
# 5       s1         12  rest   frontal  0.025421
# 6       s2         14  stim   frontal -0.063215
# 7       s3         16  rest   frontal  0.014532
# 8       s4         18  stim   frontal -0.052341
# 9       s6         20  rest   frontal  0.031245
# 10      s7         12  stim  temporal -0.024531
# 11      s8         14  rest  temporal  0.018642
# 12      s9         16  stim  temporal -0.071235
# 13     s14         18  rest  temporal  0.042156
# 14     s15         20  stim  temporal -0.035821

# %%
#Using kind="line" offers the same flexibility for semantic mappings as kind="scatter", but lineplot() transforms the data more before plotting.
sns.relplot(
    data=frmi, x="timepoint", y="signal", col="region",
    hue="event", style="event", kind="line",
)

# %%
#The size and shape of the figure is parametrized by the height and aspect ratio of each individual facet:
sns.relplot(
    data=frmi,
    x="subject", y="signal",
    hue="event", style="event", col="region",
    height=5, aspect=.86, kind="line"
)

# %%
g = sns.relplot(
    data=frmi,
    x="timepoint", y="signal",
    hue="event", style="event", col="region",
    height=4, aspect=.7, kind="line"
)
(g.map(plt.axhline, y=0, color=".7", dashes=(2, 1), zorder=0)
  .set_axis_labels("Timepoint", "Percent signal change")
  .set_titles("Region: {col_name} cortex")
  .tight_layout(w_pad=3))
#axhline ->axis horizontal line
#tight_layout() → adjusts the layout so labels, titles, and plots don't overlap.
#w_pad → controls the horizontal padding between subplots.
#w_pad=0 → sets that horizontal padding to 0 (as small as possible).

#dash(dash_len,gaplength)

# %%
g = sns.relplot(
    data=frmi,
    x="timepoint", y="signal",
    hue="event", style="event", col="region",
    height=4, aspect=.7, kind="line"
)
(g.map(plt.axhline, y=0.02, color=".7", dashes=(2, 1), zorder=0)
 .set_axis_labels("Timepoint", "Percent signal change")
 .set_titles("Region: {col_name} cortex")
 .tight_layout(w_pad=3))

# %%
sns.relplot(data=df, kind="line")

# %% [markdown]
# # ***LINEPLOT***

# %%
"""lineplot(data=None, *, x=None, y=None, hue=None, size=None, style=None, units=None, weights=None, palette=None, hue_order=None, hue_norm=None,
sizes=None, size_order=None, size_norm=None, dashes=True, markers=None, style_order=None, estimator='mean', errorbar=('ci', 95),
n_boot=1000, seed=None, orient='x', sort=True, err_style='band', err_kws=None, legend='auto', ci='deprecated', ax=None, **kwargs)"""

travel = pd.DataFrame({
    "year": [
        1949, 1949, 1949, 1949, 1949, 1949, 1949, 1949, 1949, 1949, 1949, 1949,
        1950, 1950, 1950, 1950, 1950, 1950, 1950, 1950, 1950, 1950, 1950, 1950,
        1951, 1951, 1951, 1951, 1951, 1951
    ],

    "month": [
        "Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec",
        "Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec",
        "Jan", "Feb", "Mar", "Apr", "May", "Jun"
    ],

    "passengers": [
        112, 118, 132, 129, 121, 135, 148, 148, 136, 119, 104, 118,
        115, 126, 141, 135, 125, 149, 170, 170, 158, 133, 114, 140,
        145, 150, 180, 163, 172, 178
    ]
})

print(travel)
# Out:
#     year month  passengers
# 0   1949   Jan         112
# 1   1949   Feb         118
# 2   1949   Mar         132
# 3   1949   Apr         129
# 4   1949   May         121
# 5   1949   Jun         135
# 6   1949   Jul         148
# 7   1949   Aug         148
# 8   1949   Sep         136
# 9   1949   Oct         119
# 10  1949   Nov         104
# 11  1949   Dec         118
# 12  1950   Jan         115
# 13  1950   Feb         126
# 14  1950   Mar         141
# 15  1950   Apr         135
# 16  1950   May         125
# 17  1950   Jun         149
# 18  1950   Jul         170
# 19  1950   Aug         170
# 20  1950   Sep         158
# 21  1950   Oct         133
# 22  1950   Nov         114
# 23  1950   Dec         140
# 24  1951   Jan         145
# 25  1951   Feb         150
# 26  1951   Mar         180
# 27  1951   Apr         163
# 28  1951   May         172
# 29  1951   Jun         178

# %%
sns.lineplot(data=travel,x='year',y='passengers')
plt.grid()

# %%
years = pd.DataFrame({
    "Jan": [112, 115, 145, 171, 196],
    "Feb": [118, 126, 150, 180, 196],
    "Mar": [132, 141, 178, 193, 236],
    "Apr": [129, 135, 163, 181, 235],
    "May": [121, 125, 172, 183, 229],
    "Jun": [135, 149, 178, 218, 243],
    "Jul": [148, 170, 199, 230, 264],
    "Aug": [148, 170, 199, 242, 272],
    "Sep": [136, 158, 184, 209, 237],
    "Oct": [119, 133, 162, 191, 211],
    "Nov": [104, 114, 146, 172, 180],
    "Dec": [118, 140, 166, 194, 201]
}, index=[1949, 1950, 1951, 1952, 1953])

years.index.name = "year"

print(years)
# Out:
#       Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# year
# 1949  112  118  132  129  121  135  148  148  136  119  104  118
# 1950  115  126  141  135  125  149  170  170  158  133  114  140
# 1951  145  150  178  163  172  178  199  199  184  162  146  166
# 1952  171  180  193  181  183  218  230  242  209  191  172  194
# 1953  196  196  236  235  229  243  264  272  237  211  180  201

# %%
#To plot a single vector, pass it to data.
plt.figure(figsize=[16,7])
sns.lineplot(data=years[['Jan','May','Jun','May']])
# Out:
# <Axes: xlabel='year'>

# %%
sns.lineplot(data=years)
# Out:
# <Axes: xlabel='year'>

# %%
sns.lineplot(data=travel, x="passengers", y="year", orient="x")
sns.lineplot(data=travel, x="passengers", y="year", orient="y")
# Out:
# <Axes: xlabel='passengers', ylabel='year'>

# %%
sns.lineplot(data=frmi, x="timepoint", y="signal", hue="event")
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
sns.lineplot(data=frmi, x="timepoint", y="signal", hue="event",style='region',markers=True)
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
sns.lineplot(data=frmi, x="timepoint", y="signal", hue="event",style='region',markers=True,dashes=False)
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
#error bars instead of error bands and extend them to two standard error widths:
sns.lineplot(
    data=frmi, x="timepoint", y="signal", hue="event", err_style="band", errorbar=("ci", 78),
) #errstyle-> band/bars
#error bar not occcurign because tehre only one val

'''errorbar	Meaning
"ci"	Confidence interval
"pi"	Percentile interval
"se"	Standard error
"sd"	Standard deviation
None	No error bars'''
# Out:
# 'errorbar\tMeaning\n"ci"\tConfidence interval\n"pi"\tPercentile interval\n"se"\tStandard error\n"sd"\tStandard deviation\nNone\tNo error bars'

# %%
frmi.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
#units is used when you have individual entities/groups that should each get their own line, without averaging them together.
#estimator tells Seaborn how to combine multiple y-values for the same x-value.

sns.lineplot(
    data=frmi.query("region == 'frontal'"),
    x="timepoint", y="signal", hue="event", units="subject",
    estimator=None, lw=3,
)  #lw->line width
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
dots = pd.DataFrame({
    "align": [
        "dots", "dots", "dots", "dots", "dots",
        "dots", "dots", "dots", "dots", "dots",
        "lines", "lines", "lines", "lines", "lines",
        "lines", "lines", "lines", "lines", "lines",
        "dots", "dots", "dots", "dots", "dots",
        "dots", "dots", "dots", "dots", "dots",
        "lines", "lines", "lines", "lines", "lines",
        "lines", "lines", "lines", "lines", "lines",
        "dots", "dots", "dots", "dots", "dots",
        "lines", "lines", "lines", "lines", "lines"
    ],

    "choice": [
        "T1", "T1", "T1", "T1", "T1",
        "T1", "T1", "T1", "T1", "T1",
        "T1", "T1", "T1", "T1", "T1",
        "T1", "T1", "T1", "T1", "T1",
        "T1", "T1", "T1", "T1", "T1",
        "T2", "T2", "T2", "T2", "T2",
        "T2", "T2", "T2", "T2", "T2",
        "T2", "T2", "T2", "T2", "T2",
        "T2", "T2", "T2", "T2", "T2",
        "T2", "T2", "T2", "T2", "T2"
    ],

    "time": [
        -80, -40, 0, 40, 80,
        120, 160, 200, 240, 280,
        -80, -40, 0, 40, 80,
        120, 160, 200, 240, 280,
        -80, -40, 0, 40, 80,
        120, 160, 200, 240, 280,
        -80, -40, 0, 40, 80,
        120, 160, 200, 240, 280,
        -80, -40, 0, 40, 80,
        120, 160, 200, 240, 280
    ],

    "coherence": [
        0.0, 3.2, 6.4, 12.8, 25.6,
        0.0, 3.2, 6.4, 12.8, 25.6,
        0.0, 3.2, 6.4, 12.8, 25.6,
        0.0, 3.2, 6.4, 12.8, 25.6,
        0.0, 3.2, 6.4, 12.8, 25.6,
        0.0, 3.2, 6.4, 12.8, 25.6,
        0.0, 3.2, 6.4, 12.8, 25.6,
        0.0, 3.2, 6.4, 12.8, 25.6,
        0.0, 3.2, 6.4, 12.8, 25.6,
        0.0, 3.2, 6.4, 12.8, 25.6
    ],

    "firing_rate": [
        33.19, 31.69, 34.28, 32.63, 35.06,
        34.10, 35.42, 36.18, 37.50, 39.21,
        32.45, 33.12, 35.21, 36.42, 38.15,
        35.10, 36.45, 38.20, 40.12, 42.30,
        31.87, 32.94, 34.76, 35.88, 37.64,
        34.02, 32.88, 35.43, 37.01, 40.12,
        31.94, 33.76, 35.18, 36.54, 39.27,
        33.21, 34.89, 36.12, 38.33, 41.05,
        32.67, 33.92, 35.84, 37.46, 40.38,
        34.11, 35.27, 37.05, 39.12, 42.16
    ]
})

print(dots)
# Out:
#     align choice  time  coherence  firing_rate
# 0    dots     T1   -80        0.0        33.19
# 1    dots     T1   -40        3.2        31.69
# 2    dots     T1     0        6.4        34.28
# 3    dots     T1    40       12.8        32.63
# 4    dots     T1    80       25.6        35.06
# 5    dots     T1   120        0.0        34.10
# 6    dots     T1   160        3.2        35.42
# 7    dots     T1   200        6.4        36.18
# 8    dots     T1   240       12.8        37.50
# 9    dots     T1   280       25.6        39.21
# 10  lines     T1   -80        0.0        32.45
# 11  lines     T1   -40        3.2        33.12
# 12  lines     T1     0        6.4        35.21
# 13  lines     T1    40       12.8        36.42
# 14  lines     T1    80       25.6        38.15
# 15  lines     T1   120        0.0        35.10
# 16  lines     T1   160        3.2        36.45
# 17  lines     T1   200        6.4        38.20
# 18  lines     T1   240       12.8        40.12
# ...

# %%
sns.lineplot(
    data=dots, x="time", y="firing_rate", hue="coherence", style="choice",
)
# Out:
# <Axes: xlabel='time', ylabel='firing_rate'>

# %%
# set color mapping using palette
import matplotlib as plt

sns.lineplot(
    data=dots.query("coherence > 0"),
    x="time", y="firing_rate", hue="coherence", style="choice",
     palette="rocket", hue_norm=plt.colors.LogNorm(),
)
#LogNorm() is useful when values span a range where a logarithmic scale makes the color mapping more informative.
#colors is a module inside Matplotlib that contains tools for working with colors.
'''palette="flare"
palette="viridis"
palette="magma"
palette="rocket"
palette="coolwarm"
palette="Blues"
palette="Greens"
palette="Reds" '''
# Out:
# 'palette="flare"\npalette="viridis"\npalette="magma"\npalette="rocket"\npalette="coolwarm"\npalette="Blues"\npalette="Greens"\npalette="Reds" '

# %%
palette = sns.color_palette("magma", 6)
sns.lineplot(
    data=dots, x="time", y="firing_rate",
    hue="coherence", style="choice",
    palette=palette
)

#sns.color_palette(palette=None, n_colors=None, desat=None, as_cmap=False) desat-> desaturation
#as_cmap -Return a continuous colormap instead of a list of colors
# Out:
# /tmp/ipykernel_4331/2921858692.py:2: UserWarning: The palette list has more values (6) than needed (5), which may not be intended.
#   sns.lineplot(
# <Axes: xlabel='time', ylabel='firing_rate'>

# %%
sns.lineplot(
    data=dots, x="time", y="firing_rate",
    size="coherence", hue="choice",
    legend="full"
)
# Out:
# <Axes: xlabel='time', ylabel='firing_rate'>

# %%
#Pass a a tuple, sizes=(smallest, largest), to control the range of linewidths used to map the size semantic:
sns.lineplot(
    data=dots, x="time", y="firing_rate",
    size="coherence", hue="choice",
    sizes=(.25, 2.5)
)
# Out:
# <Axes: xlabel='time', ylabel='firing_rate'>

# %%
np.random.seed(10)
x, y = np.random.normal(size=(2, 5000)).cumsum(axis=1)
sns.lineplot(x=x, y=y, sort=False, lw=1)
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=[10,7])
sns.relplot(
    data=frmi, x="timepoint", y="signal",
    col="region", hue="event", style="event",
    kind="line"
)

# %% [markdown]
# # ***DISPLOT***

# %%
'''displot(data=None, *, x=None, y=None, hue=None, row=None, col=None, weights=None, kind='hist', rug=False, rug_kws=None,
log_scale=None, legend=True, palette=None, hue_order=None, hue_norm=None, color=None, col_wrap=None, row_order=None, col_order=None,
 height=5, aspect=1, facet_kws=None, **kwargs)'''
 #displot() → distribution of data.It helps you understand how values are distributed.

penguins = sns.load_dataset("penguins")
sns.displot(data=penguins, x="flipper_length_mm")

# %%
sns.displot(data=penguins, x="flipper_length_mm", kind="kde")

# %%
sns.displot(data=penguins, x="flipper_length_mm", kind="ecdf")

# %%
#adding kde curve in histogram
sns.displot(data=penguins, x="flipper_length_mm", kde=True)

# %%
sns.displot(data=penguins, x="flipper_length_mm", y="bill_length_mm",hue='island',palette='magma')

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
sns.displot(data=penguins, x="flipper_length_mm", y="bill_length_mm",hue='island', kind="kde")

# %%
g = sns.displot(data=penguins, x="flipper_length_mm", y="bill_length_mm", kind="kde", rug=True)
#Make the distribution plot AND show where the individual data points are located.

# %%
sns.displot(data=penguins, x="flipper_length_mm", hue="species", kind="kde")

# %%
sns.displot(data=penguins, x="flipper_length_mm", hue="species", multiple="layer")
'''layer (Default): Plots subsets on top of each other with transparency.
   dodge: Places bars side-by-side in separate columns to prevent overlap.
   stack: Stacks bars vertically on top of each other within the same bin.
   fill: Stacks bars vertically and normalises them to show relative proportions (percentages)
   adding up to 100%.'''
# Out:
# 'layer (Default): Plots subsets on top of each other with transparency.\n   dodge: Places bars side-by-side in separate columns to prevent overlap.\n   stack: Stacks bars vertically on top of each other within the same bin.\n   fill: Stacks bars vertically and normalises them to show relative proportions (percentages) \n   adding up to 100%.'

# %%
sns.displot(data=penguins, x="flipper_length_mm", hue="species", col="sex", kind="kde")
plt.figure(figsize=(10,6))

# %%
sns.displot(
    data=penguins, y="flipper_length_mm", hue="sex", col="species",
    kind="ecdf", height=5, aspect=.6,
)
